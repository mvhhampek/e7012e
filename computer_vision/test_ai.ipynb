# %%
from ai import ai
from PIL import Image
import matplotlib.pyplot as plt

a = ai("model_scripted.pt")

# %%
img = Image.open("teat_ai2.jpg")
plt.imshow(img)
print(a.predict_image(img))
# Out:
# 2
