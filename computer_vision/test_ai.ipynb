# %%
from ai import ai
from PIL import Image
import matplotlib.pyplot as plt

a = ai("model_scripted2.pt")

# %%
img = Image.open("redtest.jpg")
print(type(img))
plt.imshow(img)
print(a.predict_image(img))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# tensor([[-34.6447,  30.7676, -48.6626]], grad_fn=<DifferentiableGraphBackward>)
# 1
