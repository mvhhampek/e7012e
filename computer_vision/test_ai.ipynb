# %%
from ai import ai
from PIL import Image
import matplotlib.pyplot as plt

a = ai("model_scripted.pt")

# %%
img = Image.open("data\\Images\\green130.jpg")
plt.imshow(img)
print(a.predict_image(img))
# Out:
# 0
